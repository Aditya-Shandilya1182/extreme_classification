# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-Shandilya1182/extreme_classification/blob/main/extreme_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import gensim
import numpy as np

# %%
import json

# %%
file_path_train = '/content/drive/MyDrive/LF-Amazon-131K.raw/LF-Amazon-131K/trn.json.gz'
with open(file_path_train, 'r') as file:
    json_data_train = json.load(file)

# %%
file_path_test = '/content/drive/MyDrive/LF-Amazon-131K.raw/LF-Amazon-131K/tst.json'

# Initialize an empty list to store valid JSON objects
json_data_test_list = []

# Open the file and load each JSON object, skipping lines with decoding errors
with open(file_path_test, 'r') as file:
    for line_number, line in enumerate(file, start=1):
        try:
            json_data = json.loads(line)
            json_data_test_list.append(json_data)
        except json.JSONDecodeError as e:
            print(f"Skipping line {line_number} due to JSON decoding error: {e}")

# Now json_data_list contains valid JSON objects, and you can proceed to use it as needed

# %%
import json

file_path_train = '/content/drive/MyDrive/LF-Amazon-131K.raw/LF-Amazon-131K/trn.json'

# Initialize an empty list to store valid JSON objects
json_data_train_list = []

# Open the file and load each JSON object, skipping lines with decoding errors
with open(file_path_train, 'r') as file:
    for line_number, line in enumerate(file, start=1):
        try:
            json_data = json.loads(line)
            json_data_train_list.append(json_data)
        except json.JSONDecodeError as e:
            print(f"Skipping line {line_number} due to JSON decoding error: {e}")

# Now json_data_train_list contains valid JSON objects, and you can proceed to use it as needed

# %%
df_test = pd.DataFrame(json_data_test_list)
df_train = pd.DataFrame(json_data_train_list)

# %%
df_test.head()
# Out:
#           uid                                              title  \
# 0  B0009A41VK  Handel: Messiah / Athalia / Esther / La Resurr...
# 1  B0002QNKW2  Amazon.com: Playtex Women's Cross Your Heart L...
# 2  B0002UW95W  Shrek - The Story So Far (Shrek 1 & 2 Full Scr...
# 3  B000IX8DNK            Dashboard Doll - Hula Girl with Ukulele
# 4  B0002KVIKY                        Sarah Plain and Tall (1990)
#
#                                              content  \
# 0  Led by Christopher Hogwood, the Academy of Anc...
# 1  Style #655.  Our best selling Cross Your Heart...
# 2  SHREK: THE STORY SO FAR (4-Disc DVD Collection...
# 3   Pretty Leilani Hula Girl measuring 7 inches tall
# 4  The original 1990 release that started the ser...
#
#                        target_ind            target_rel
# 0                  [42537, 43834]            [1.0, 1.0]
# 1  [89490, 89491, 118419, 118424]  [1.0, 1.0, 1.0, 1.0]
# 2                        [125775]                 [1.0]
# ...

# %%
df_train.head()
# Out:
#           uid                                              title  \
# 0  B0007J0FJ0  Methodical Bible study: A new approach to herm...
# 1  B000LFUKV8  GeoPuzzle U.S.A. and Canada - Educational Geog...
# 2  B000NDFLWG                            In Debt We Trust (2007)
# 3  B000EVWEMW              Equus 8244 Oil Pressure Gauge - Black
# 4  B000FMWGZ0  Spur Gear, 20 Degree Pressure Angle, Polyoxyme...
#
#                                              content  \
# 0  Inductive study compares related Bible texts i...
# 1  GeoPuzzles are jigsaw puzzles that make learni...
# 2  Just a few decades ago, owing more money than ...
# 3  This black oil pressure gauge is engineered to...
# 4  This polyoxymethylene spur gear with 20-degree...
#
#                  target_ind       target_rel
# 0                    [4315]            [1.0]
# 1          [112532, 113827]       [1.0, 1.0]
# 2          [117566, 127037]       [1.0, 1.0]
# 3  [102958, 102959, 102963]  [1.0, 1.0, 1.0]
# ...

# %%
import json

file_path_label = '/content/drive/MyDrive/LF-Amazon-131K.raw/LF-Amazon-131K/lbl.json'

# Initialize an empty list to store valid JSON objects
json_data_label_list = []

# Open the file and load each JSON object, skipping lines with decoding errors
with open(file_path_label, 'r') as file:
    for line_number, line in enumerate(file, start=1):
        try:
            json_data = json.loads(line)
            json_data_label_list.append(json_data)
        except json.JSONDecodeError as e:
            print(f"Skipping line {line_number} due to JSON decoding error: {e}")

# Now json_data_train_list contains valid JSON objects, and you can proceed to use it as needed

# %%
df_label = pd.DataFrame(json_data_label_list)

# %%
df_label.head()
# Out:
#           uid                                              title content  \
# 0  0001055313                                       Hundred Days
# 1  0001837397                         Autumn Story Brambly Hedge
# 2  0002154129  France: The Beautiful Cookbook- Authentic Reci...
# 3  0002154463  Italy, The Beautiful Cookbook: Authentic Recip...
# 4  000215725X                    City of Djinns: A Year in Delhi
#
#   target_ind target_rel
# 0         []         []
# 1         []         []
# 2         []         []
# 3         []         []
# 4         []         []

# %%
df_test.isnull().sum()
# Out:
# uid           0
# title         0
# content       0
# target_ind    0
# target_rel    0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# uid           0
# title         0
# content       0
# target_ind    0
# target_rel    0
# dtype: int64

# %%
len(df_test)
# Out:
# 134835

# %%
len(df_train)
# Out:
# 294805

# %%
df_test['title'] = df_test['title'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df_test.head()
# Out:
#           uid                                              title  \
# 0  B0009A41VK  handel: messiah / athalia / esther / la resurr...
# 1  B0002QNKW2  amazon.com: playtex women's cross your heart l...
# 2  B0002UW95W  shrek - the story so far (shrek 1 & 2 full scr...
# 3  B000IX8DNK            dashboard doll - hula girl with ukulele
# 4  B0002KVIKY                        sarah plain and tall (1990)
#
#                                              content  \
# 0  Led by Christopher Hogwood, the Academy of Anc...
# 1  Style #655.  Our best selling Cross Your Heart...
# 2  SHREK: THE STORY SO FAR (4-Disc DVD Collection...
# 3   Pretty Leilani Hula Girl measuring 7 inches tall
# 4  The original 1990 release that started the ser...
#
#                        target_ind            target_rel
# 0                  [42537, 43834]            [1.0, 1.0]
# 1  [89490, 89491, 118419, 118424]  [1.0, 1.0, 1.0, 1.0]
# 2                        [125775]                 [1.0]
# ...

# %%
df_train['title'] = df_train['title'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df_train.head()
# Out:
#           uid                                              title  \
# 0  B0007J0FJ0  methodical bible study: a new approach to herm...
# 1  B000LFUKV8  geopuzzle u.s.a. and canada - educational geog...
# 2  B000NDFLWG                            in debt we trust (2007)
# 3  B000EVWEMW              equus 8244 oil pressure gauge - black
# 4  B000FMWGZ0  spur gear, 20 degree pressure angle, polyoxyme...
#
#                                              content  \
# 0  Inductive study compares related Bible texts i...
# 1  GeoPuzzles are jigsaw puzzles that make learni...
# 2  Just a few decades ago, owing more money than ...
# 3  This black oil pressure gauge is engineered to...
# 4  This polyoxymethylene spur gear with 20-degree...
#
#                  target_ind       target_rel
# 0                    [4315]            [1.0]
# 1          [112532, 113827]       [1.0, 1.0]
# 2          [117566, 127037]       [1.0, 1.0]
# 3  [102958, 102959, 102963]  [1.0, 1.0, 1.0]
# ...

# %%
df_test['title'] = df_test['title'].str.replace('[^\w\s]',' ')
# Out:
# <ipython-input-39-54a121ed81c1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_test['title'] = df_test['title'].str.replace('[^\w\s]',' ')

# %%
df_train['title'] = df_train['title'].str.replace('[^\w\s]',' ')
# Out:
# <ipython-input-40-076972574e3d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_train['title'] = df_train['title'].str.replace('[^\w\s]',' ')

# %%
df_train.head()
# Out:
#           uid                                              title  \
# 0  B0007J0FJ0  methodical bible study  a new approach to herm...
# 1  B000LFUKV8  geopuzzle u s a  and canada   educational geog...
# 2  B000NDFLWG                            in debt we trust  2007
# 3  B000EVWEMW              equus 8244 oil pressure gauge   black
# 4  B000FMWGZ0  spur gear  20 degree pressure angle  polyoxyme...
#
#                                              content  \
# 0  Inductive study compares related Bible texts i...
# 1  GeoPuzzles are jigsaw puzzles that make learni...
# 2  Just a few decades ago, owing more money than ...
# 3  This black oil pressure gauge is engineered to...
# 4  This polyoxymethylene spur gear with 20-degree...
#
#                  target_ind       target_rel
# 0                    [4315]            [1.0]
# 1          [112532, 113827]       [1.0, 1.0]
# 2          [117566, 127037]       [1.0, 1.0]
# 3  [102958, 102959, 102963]  [1.0, 1.0, 1.0]
# ...

# %%
df_test.head()
# Out:
#           uid                                              title  \
# 0  B0009A41VK  handel  messiah   athalia   esther   la resurr...
# 1  B0002QNKW2  amazon com  playtex women s cross your heart l...
# 2  B0002UW95W  shrek   the story so far  shrek 1   2 full scr...
# 3  B000IX8DNK            dashboard doll   hula girl with ukulele
# 4  B0002KVIKY                        sarah plain and tall  1990
#
#                                              content  \
# 0  Led by Christopher Hogwood, the Academy of Anc...
# 1  Style #655.  Our best selling Cross Your Heart...
# 2  SHREK: THE STORY SO FAR (4-Disc DVD Collection...
# 3   Pretty Leilani Hula Girl measuring 7 inches tall
# 4  The original 1990 release that started the ser...
#
#                        target_ind            target_rel
# 0                  [42537, 43834]            [1.0, 1.0]
# 1  [89490, 89491, 118419, 118424]  [1.0, 1.0, 1.0, 1.0]
# 2                        [125775]                 [1.0]
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df_train['title'] = df_train['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df_train['content'] = df_train['content'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df_test['title'] = df_test['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df_test['content'] = df_test['content'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from textblob import Word
df_test['title'] = df_test['title'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
from textblob import Word
df_train['title'] = df_train['title'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
df_test.head()
# Out:
#           uid                                              title  \
# 0  B0009A41VK      handel messiah athalia esther la resurrezione
# 1  B0002QNKW2  amazon com playtex woman cross heart lightly l...
# 2  B0002UW95W  shrek story far shrek 1 2 full screen shrek 3d...
# 3  B000IX8DNK                   dashboard doll hula girl ukulele
# 4  B0002KVIKY                              sarah plain tall 1990
#
#                                              content  \
# 0  Led Christopher Hogwood, Academy Ancient Music...
# 1  Style #655. Our best selling Cross Your Heart ...
# 2  SHREK: THE STORY SO FAR (4-Disc DVD Collection...
# 3   Pretty Leilani Hula Girl measuring 7 inches tall
# 4  The original 1990 release started series. Incl...
#
#                        target_ind            target_rel
# 0                  [42537, 43834]            [1.0, 1.0]
# 1  [89490, 89491, 118419, 118424]  [1.0, 1.0, 1.0, 1.0]
# 2                        [125775]                 [1.0]
# ...

# %%
df_train.head()
# Out:
#           uid                                              title  \
# 0  B0007J0FJ0   methodical bible study new approach hermeneutics
# 1  B000LFUKV8  geopuzzle u canada educational geography jigsa...
# 2  B000NDFLWG                                    debt trust 2007
# 3  B000EVWEMW                equus 8244 oil pressure gauge black
# 4  B000FMWGZ0  spur gear 20 degree pressure angle polyoxymeth...
#
#                                              content  \
# 0  Inductive study compares related Bible texts o...
# 1  GeoPuzzles jigsaw puzzles make learning world ...
# 2  Just decades ago, owing money bank account exc...
# 3  This black oil pressure gauge engineered provi...
# 4  This polyoxymethylene spur gear 20-degree pres...
#
#                  target_ind       target_rel
# 0                    [4315]            [1.0]
# 1          [112532, 113827]       [1.0, 1.0]
# 2          [117566, 127037]       [1.0, 1.0]
# 3  [102958, 102959, 102963]  [1.0, 1.0, 1.0]
# ...
